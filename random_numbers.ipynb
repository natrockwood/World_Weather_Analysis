# %%
import random

# %%
random.random()
# Creates a random floating point number
# Out:
# 0.5157482496704613

# %%
random.randint(-10,10)
# Producing a random integer between the range, can jump from upper boundary to lower boundary
# Out:
# -4

# %%
random.randrange(-9,9,2)
# Limited by the 'step' argument: takes steps from the lower to upper boundary
# Out:
# -7

# %%
random.uniform(-10,10)
# Not an integer value, has multiple decimals
# Out:
# 0.6913986190453443

# %%
x = 1
latitudes = []
while x < 11:
    random_lat = random.randint(-90, 90) + random.random()
    latitudes.append(random_lat)
    x += 1

latitudes
# Out:
# [-5.088004152363797,
#  53.70909801945532,
#  1.056494660038442,
#  49.09138508217417,
#  -68.9060464429459,
#  -69.27240815972552,
#  5.327935181217024,
#  6.876666314220319,
#  0.6050282633745263,
#  -48.239665249882584]

# %%
# Import the NumPy module.
import numpy as np

# %%
# Import timeit.
import timeit

# %%
# %timeit np.random.uniform(-90000, 90000, size=1500)
# Out:
# 14.2 µs ± 298 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %%
def latitudes(size):
    latitudes = []
    x = 0
    while x < (size):
        random_lat = random.randint(-90, 90) + random.random()
        latitudes.append(random_lat)
        x += 1
    return latitudes
# Call the function with 1500. 
# %timeit latitudes(1500)
# Out:
# 1.75 ms ± 56.1 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
# Skill Drill: Refactor the code for the while loop with the %timeit magic command and
# write a for loop that will generate the 1,500 latitudes.
def latitudes(size):
    latitudes = []
    x = 0
    while x < (size):
        random_lat = random.randint(-90, 90) + random.random()
        latitudes.append(random_lat)
        x += 1
    
    for i in latitudes:
        print(i)
    
# Call the function with 1500. 
# %timeit latitudes(1500)
# Out:
# -6.129072927101808
# 34.22173629303137
# 60.29538109076065
# -21.39274164820563
# -57.19163265250264
# -18.378120867752315
# 16.758969361234822
# -15.295013719846418
# 68.80525302796303
# -89.83376928472964
# 3.135210467099936
# -32.59015285934077
# 58.74011205599563
# -2.9087934638259165
# -9.949982552720545
# -21.828041309423828
# 48.22977212068298
# -67.44671571608833
# -32.15087043518434
# -0.657392644926687
# 78.35445693476682
# -70.36270348899332
# 40.66080408961766
# -55.97375501087512
# 27.36987186926855
# -84.60689240324511
# 17.345351585561595
# -51.392344416493344
# -11.354304981549992
# -85.25987600886931
# 62.46100823527856
# -81.8717518066953
# 32.44905676233116
# -34.38913590269554
# -41.916495142780064
# -3.690011626743097
# -17.743182638491287
# 36.91504740458375
# 24.121234321562667
# 80.84786369889848
# -24.21368408409039
# -17.25425549010153
# -85.04007195070356
# -53.054057439041806
# -85.527840212852
# -75.1122615300375
# -80.04512614140803
# 81.41614207125215
# ...
