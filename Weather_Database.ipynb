# %% [markdown]
# ### Get the Weather Description and Amount of Precipitation for Each City

# %%
# Import dependencies

import random
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests
import traceback

# %%
# Create a new set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %% [markdown]
# #### Get the nearest city using the citipy module.

# %%
# Import citipy module
from citipy import citipy

# %%
# Use the tuple() function to display the latitude and longitude combinations.
for coordinate in coordinates:
    print(citipy.nearest_city(coordinate[0], coordinate[1]).city_name,
          citipy.nearest_city(coordinate[0], coordinate[1]).country_code)
# Out:
# lagoa pt
# kapaa us
# cayenne gf
# vestmannaeyjar is
# richards bay za
# pahrump us
# severo-kurilsk ru
# barentsburg sj
# chuy uy
# qaanaaq gl
# mount gambier au
# rikitea pf
# lebu cl
# kirakira sb
# saint-philippe re
# provideniya ru
# victoria sc
# hasaki jp
# kaeo nz
# port alfred za
# tuatapere nz
# tuatapere nz
# port alfred za
# gizo sb
# esperance au
# najran sa
# khatanga ru
# snyder us
# malanje ao
# ushuaia ar
# san cristobal ec
# new norfolk au
# tasiilaq gl
# albany au
# faya td
# akyab mm
# cao bang vn
# tsihombe mg
# albany au
# bilibino ru
# haringhata in
# rikitea pf
# ossora ru
# nikolskoye ru
# careiro da varzea br
# saint-philippe re
# amderma ru
# ushuaia ar
# rikitea pf
# chokurdakh ru
# labuhan id
# bredasdorp za
# rikitea pf
# longlac ca
# sola vu
# hermanus za
# kysyl-syr ru
# katsuura jp
# barrow us
# saldanha za
# cayenne gf
# butaritari ki
# mataura pf
# ushuaia ar
# buchanan lr
# sotouboua tg
# mount isa au
# pevek ru
# isakly ru
# kjollefjord no
# boa vista br
# mataura pf
# severo-kurilsk ru
# cape town za
# qaanaaq gl
# kasempa zm
# hilo us
# puerto ayora ec
# talcahuano cl
# saint-orens-de-gameville fr
# rikitea pf
# mtambile tz
# khatanga ru
# bredasdorp za
# kodiak us
# durban za
# marzuq ly
# tuktoyaktuk ca
# tezu in
# hobart au
# la palma pa
# saint-philippe re
# yatou cn
# half moon bay us
# san juan ar
# kavaratti in
# hamilton us
# rikitea pf
# lamar us
# henties bay na
# aklavik ca
# puerto ayora ec
# illoqqortoormiut gl
# walvis bay na
# longyearbyen sj
# mataura pf
# baykit ru
# leningradskiy ru
# besikduzu tr
# bagotville ca
# butaritari ki
# barrow us
# mlimba tz
# khrebtovaya ru
# saint-philippe re
# longyearbyen sj
# launceston au
# kapaa us
# ketchikan us
# barentsburg sj
# katangli ru
# pangnirtung ca
# esperance au
# cape town za
# rawson ar
# cayenne gf
# qaanaaq gl
# rikitea pf
# sao filipe cv
# mount isa au
# pavlovskiy ru
# provideniya ru
# cape town za
# albany au
# liverpool ca
# rio do sul br
# atherton au
# coolum beach au
# sentyabrskiy ru
# yellowknife ca
# sorvag fo
# bargal so
# barentsburg sj
# punta arenas cl
# saint-philippe re
# leh in
# saint-ambroise ca
# mataura pf
# hobyo so
# aksarayskiy ru
# souillac mu
# avarua ck
# rikitea pf
# cape town za
# ushuaia ar
# moron mn
# ushuaia ar
# gueret fr
# rikitea pf
# kodiak us
# saint george bm
# dudinka ru
# mataura pf
# dire dawa et
# bluff nz
# aleksandrov gay ru
# wajima jp
# provideniya ru
# lebu cl
# bredasdorp za
# ushuaia ar
# lavrentiya ru
# thompson ca
# mataura pf
# valparaiso cl
# busselton au
# souillac mu
# hilo us
# busselton au
# luderitz na
# borgarnes is
# thompson ca
# russell nz
# mar del plata ar
# mar del plata ar
# albany au
# amahai id
# avarua ck
# georgetown sh
# cabo san lucas mx
# nikolskoye ru
# lillers fr
# victoria sc
# longyearbyen sj
# bengkulu id
# avarua ck
# torbay ca
# yuzhno-kurilsk ru
# west wendover us
# rikitea pf
# bluff nz
# sandur in
# albany au
# tasiilaq gl
# busselton au
# rawson ar
# taolanaro mg
# nanortalik gl
# puerto ayora ec
# puerto baquerizo moreno ec
# samarai pg
# rikitea pf
# greystones ie
# broome au
# cape town za
# marawi sd
# carnarvon au
# albany au
# hermanus za
# tual id
# busselton au
# victoria ar
# nikolskoye ru
# rikitea pf
# castro cl
# namibe ao
# shelburne ca
# rikitea pf
# erdenet mn
# lima pe
# hilo us
# illoqqortoormiut gl
# saint george bm
# hervey bay au
# ancud cl
# mergui mm
# barentsburg sj
# mataura pf
# ushuaia ar
# thompson ca
# olinda br
# yumen cn
# albany au
# saint-philippe re
# taolanaro mg
# aborlan ph
# saint-philippe re
# vaini to
# rikitea pf
# busselton au
# chokurdakh ru
# saint george bm
# bluff nz
# saint george bm
# fasa ir
# vardo no
# iralaya hn
# vaini to
# kahului us
# yellowknife ca
# lyman ua
# taolanaro mg
# chuy uy
# severo-kurilsk ru
# san quintin mx
# sampit id
# port alfred za
# seoul kr
# butaritari ki
# palompon ph
# broome au
# taolanaro mg
# punta arenas cl
# mataura pf
# ribeira grande pt
# mar del plata ar
# galesong id
# roswell us
# paamiut gl
# bluff nz
# castro cl
# avera pf
# senanga zm
# provideniya ru
# bluff nz
# darakert am
# busselton au
# anzio it
# melchor de mencos gt
# rikitea pf
# port hueneme us
# nizhneyansk ru
# slave lake ca
# amapa br
# esperance au
# punta arenas cl
# punta arenas cl
# rikitea pf
# rikitea pf
# dikson ru
# jamestown sh
# punta arenas cl
# port keats au
# puerto ayora ec
# esperance au
# provideniya ru
# agapovka ru
# taolanaro mg
# mys shmidta ru
# qaanaaq gl
# bredasdorp za
# tokonou gn
# malindi ke
# baiyin cn
# mar del plata ar
# mbanza-ngungu cd
# upernavik gl
# hermanus za
# muzhi ru
# pevek ru
# labutta mm
# thompson ca
# atuona pf
# opuwo na
# kapaa us
# husavik is
# butaritari ki
# rikitea pf
# lebu cl
# bredasdorp za
# upernavik gl
# vaitupu wf
# laguna br
# atuona pf
# atuona pf
# tsihombe mg
# manitouwadge ca
# kristianstad se
# cherskiy ru
# rikitea pf
# albany au
# taolanaro mg
# katsuura jp
# saskylakh ru
# severo-kurilsk ru
# cururupu br
# excelsior springs us
# constitucion mx
# lebu cl
# busselton au
# souillac mu
# soanierana ivongo mg
# shubarkuduk kz
# loum cm
# busselton au
# aswan eg
# albany au
# sabang id
# sabang id
# codrington ag
# fortuna us
# albany au
# qaanaaq gl
# albany au
# castro cl
# shekhupura pk
# hermanus za
# ushuaia ar
# arraial do cabo br
# dekar bw
# kawalu id
# nizhneyansk ru
# constitucion mx
# hilo us
# nalut ly
# castro cl
# bolungarvik is
# longyearbyen sj
# tuktoyaktuk ca
# punta arenas cl
# bluff nz
# ornskoldsvik se
# chimoio mz
# kokhma ru
# ushuaia ar
# nisia floresta br
# asau tv
# ponta do sol cv
# punta arenas cl
# labuhan id
# busselton au
# tuatapere nz
# cherskiy ru
# thompson ca
# nikolskoye ru
# puerto ayora ec
# rikitea pf
# katha mm
# bluff nz
# rikitea pf
# faenza it
# salalah om
# neman ru
# amazar ru
# kodiak us
# rio grande br
# butaritari ki
# hilo us
# vaini to
# albany au
# faanui pf
# paris us
# mar del plata ar
# san patricio mx
# nizhneyansk ru
# piacabucu br
# geraldton au
# taolanaro mg
# rikitea pf
# khatanga ru
# rikitea pf
# lebu cl
# qaanaaq gl
# kovdor ru
# rikitea pf
# kamskiye polyany ru
# talara pe
# avarua ck
# hwange zw
# port macquarie au
# severo-kurilsk ru
# puerto ayora ec
# jamestown sh
# leningradskiy ru
# port alfred za
# cidreira br
# coquimbo cl
# hithadhoo mv
# torbay ca
# mataura pf
# aksu kz
# faanui pf
# busselton au
# louisbourg ca
# ushuaia ar
# taolanaro mg
# ancud cl
# bairiki ki
# yellowknife ca
# yar-sale ru
# barrow us
# pevek ru
# punta arenas cl
# butaritari ki
# mizdah ly
# galveston us
# busselton au
# yellowknife ca
# aklavik ca
# ushuaia ar
# ushuaia ar
# coquimbo cl
# margate za
# rikitea pf
# luderitz na
# cape town za
# yellowknife ca
# atuona pf
# vaini to
# narsaq gl
# taolanaro mg
# cape town za
# hobart au
# puerto ayora ec
# kapaa us
# yellowknife ca
# warwick au
# mae ramat th
# grand river south east mu
# jamestown sh
# lashio mm
# hofn is
# tulun ru
# castro cl
# kloulklubed pw
# mataura pf
# pecos us
# taolanaro mg
# lapeer us
# grindavik is
# jamestown sh
# raga sd
# hwange zw
# port alfred za
# jamestown sh
# kutum sd
# carlisle gb
# busselton au
# saint-philippe re
# taolanaro mg
# tungkang tw
# tasiilaq gl
# anadyr ru
# hovd mn
# egvekinot ru
# vaini to
# sao felix do xingu br
# yellowknife ca
# ciudad bolivar ve
# chuy uy
# jamestown sh
# ponta do sol cv
# mar del plata ar
# buala sb
# rikitea pf
# barrow us
# hithadhoo mv
# gavrilovka ru
# hasaki jp
# portland au
# auki sb
# altay cn
# antofagasta cl
# lebu cl
# saskylakh ru
# jamestown sh
# hasaki jp
# bluff nz
# sterling us
# ribeira grande pt
# morros br
# la ronge ca
# hithadhoo mv
# belushya guba ru
# cape town za
# punta arenas cl
# tromso no
# broome au
# saint-augustin ca
# havelock us
# hilo us
# cape town za
# bengkulu id
# bredasdorp za
# tual id
# umm kaddadah sd
# yerofey pavlovich ru
# kruisfontein za
# barrow us
# abiy adi et
# saint-augustin ca
# east london za
# pacific grove us
# tres arroyos ar
# dumas us
# severo-kurilsk ru
# port alfred za
# hilo us
# butaritari ki
# taolanaro mg
# esperance au
# castro cl
# dubenskiy ru
# pathein mm
# albany au
# mar del plata ar
# tuktoyaktuk ca
# coffeyville us
# khatanga ru
# busselton au
# severo-kurilsk ru
# nibe dk
# thessalon ca
# marcona pe
# upernavik gl
# vaitupu wf
# albany au
# aleksandrov gay ru
# atuona pf
# saint-georges gf
# wahran dz
# avarua ck
# dogondoutchi ne
# nurlat ru
# severo-kurilsk ru
# longyearbyen sj
# ushuaia ar
# bluff nz
# rikitea pf
# makakilo city us
# pocone br
# guayaramerin bo
# ribeira grande pt
# riyadh sa
# rikitea pf
# kailua us
# aranda de duero es
# palmer us
# komsomolskiy ru
# naze jp
# vila vu
# georgetown sh
# sao filipe cv
# hilo us
# mariinsk ru
# rikitea pf
# mount isa au
# carnarvon au
# punta arenas cl
# vaini to
# chunoyar ru
# jamestown sh
# pangnirtung ca
# hobart au
# palmas br
# linshu cn
# port alfred za
# cape town za
# taolanaro mg
# bolzano it
# batagay-alyta ru
# deseronto ca
# ushuaia ar
# hobart au
# saleaula ws
# ribeira grande pt
# bengkulu id
# geraldton ca
# ushuaia ar
# hermanus za
# avarua ck
# cape town za
# nanortalik gl
# southbridge nz
# madang pg
# klaksvik fo
# hamilton bm
# dzaoudzi yt
# sapa ph
# mecca sa
# banamba ml
# hilo us
# busselton au
# hermanus za
# hihifo to
# dovbysh ua
# qaqortoq gl
# hermanus za
# tautira pf
# punta arenas cl
# jamestown sh
# lebu cl
# lebu cl
# lagoa pt
# hofn is
# saleaula ws
# darhan mn
# rio gallegos ar
# hasaki jp
# provideniya ru
# severo-kurilsk ru
# albany au
# attawapiskat ca
# rikitea pf
# ribeira grande pt
# ipora br
# saint-augustin ca
# punta arenas cl
# taolanaro mg
# ushuaia ar
# ijaki ki
# mehamn no
# fortuna us
# barrow us
# port alfred za
# rosario do sul br
# verkhoshizhemye ru
# hofn is
# port lincoln au
# tasiilaq gl
# tuktoyaktuk ca
# bubaque gw
# busselton au
# rikitea pf
# norman wells ca
# belushya guba ru
# haines junction ca
# barrow us
# aklavik ca
# banda aceh id
# hamilton bm
# kodiak us
# broome au
# puerto ayora ec
# yellowknife ca
# bababe mr
# pilar ph
# gizo sb
# busselton au
# albany au
# hobart au
# yellowknife ca
# cockburn town tc
# sao filipe cv
# poshekhonye ru
# klaksvik fo
# hobart au
# emerald au
# rio grande br
# butaritari ki
# ugoofaaru mv
# korla cn
# puerto ayora ec
# petatlan mx
# weligama lk
# cape town za
# safaga eg
# khatanga ru
# rikitea pf
# puerto ayora ec
# baruun-urt mn
# punta arenas cl
# carnarvon au
# saint-pierre pm
# mataura pf
# ostrovnoy ru
# mar del plata ar
# benguela ao
# ilulissat gl
# mys shmidta ru
# khatanga ru
# boa vista br
# saint-philippe re
# mataura pf
# blonduos is
# dingle ie
# hilo us
# punta arenas cl
# bluff nz
# boende cd
# longyearbyen sj
# port elizabeth za
# lusambo cd
# norman wells ca
# yellowknife ca
# kaitangata nz
# le mars us
# ushuaia ar
# huilong cn
# bredasdorp za
# karaul ru
# puerto ayora ec
# %%
# Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
        
print(cities)
# Out:
# ['lagoa', 'kapaa', 'cayenne', 'vestmannaeyjar', 'richards bay', 'pahrump', 'severo-kurilsk', 'barentsburg', 'chuy', 'qaanaaq', 'mount gambier', 'rikitea', 'lebu', 'kirakira', 'saint-philippe', 'provideniya', 'victoria', 'hasaki', 'kaeo', 'port alfred', 'tuatapere', 'gizo', 'esperance', 'najran', 'khatanga', 'snyder', 'malanje', 'ushuaia', 'san cristobal', 'new norfolk', 'tasiilaq', 'albany', 'faya', 'akyab', 'cao bang', 'tsihombe', 'bilibino', 'haringhata', 'ossora', 'nikolskoye', 'careiro da varzea', 'amderma', 'chokurdakh', 'labuhan', 'bredasdorp', 'longlac', 'sola', 'hermanus', 'kysyl-syr', 'katsuura', 'barrow', 'saldanha', 'butaritari', 'mataura', 'buchanan', 'sotouboua', 'mount isa', 'pevek', 'isakly', 'kjollefjord', 'boa vista', 'cape town', 'kasempa', 'hilo', 'puerto ayora', 'talcahuano', 'saint-orens-de-gameville', 'mtambile', 'kodiak', 'durban', 'marzuq', 'tuktoyaktuk', 'tezu', 'hobart', 'la palma', 'yatou', 'half moon bay', 'san juan', 'kavaratti', 'hamilton', 'lamar', 'henties bay', 'aklavik', 'illoqqortoormiut', 'walvis bay', 'longyearbyen', 'baykit', 'leningradskiy', 'besikduzu', 'bagotville', 'mlimba', 'khrebtovaya', 'launceston', 'ketchikan', 'katangli', 'pangnirtung', 'rawson', 'sao filipe', 'pavlovskiy', 'liverpool', 'rio do sul', 'atherton', 'coolum beach', 'sentyabrskiy', 'yellowknife', 'sorvag', 'bargal', 'punta arenas', 'leh', 'saint-ambroise', 'hobyo', 'aksarayskiy', 'souillac', 'avarua', 'moron', 'gueret', 'saint george', 'dudinka', 'dire dawa', 'bluff', 'aleksandrov gay', 'wajima', 'lavrentiya', 'thompson', 'valparaiso', 'busselton', 'luderitz', 'borgarnes', 'russell', 'mar del plata', 'amahai', 'georgetown', 'cabo san lucas', 'lillers', 'bengkulu', 'torbay', 'yuzhno-kurilsk', 'west wendover', 'sandur', 'taolanaro', 'nanortalik', 'puerto baquerizo moreno', 'samarai', 'greystones', 'broome', 'marawi', 'carnarvon', 'tual', 'castro', 'namibe', 'shelburne', 'erdenet', 'lima', 'hervey bay', 'ancud', 'mergui', 'olinda', 'yumen', 'aborlan', 'vaini', 'fasa', 'vardo', 'iralaya', 'kahului', 'lyman', 'san quintin', 'sampit', 'seoul', 'palompon', 'ribeira grande', 'galesong', 'roswell', 'paamiut', 'avera', 'senanga', 'darakert', 'anzio', 'melchor de mencos', 'port hueneme', 'nizhneyansk', 'slave lake', 'amapa', 'dikson', 'jamestown', 'port keats', 'agapovka', 'mys shmidta', 'tokonou', 'malindi', 'baiyin', 'mbanza-ngungu', 'upernavik', 'muzhi', 'labutta', 'atuona', 'opuwo', 'husavik', 'vaitupu', 'laguna', 'manitouwadge', 'kristianstad', 'cherskiy', 'saskylakh', 'cururupu', 'excelsior springs', 'constitucion', 'soanierana ivongo', 'shubarkuduk', 'loum', 'aswan', 'sabang', 'codrington', 'fortuna', 'shekhupura', 'arraial do cabo', 'dekar', 'kawalu', 'nalut', 'bolungarvik', 'ornskoldsvik', 'chimoio', 'kokhma', 'nisia floresta', 'asau', 'ponta do sol', 'katha', 'faenza', 'salalah', 'neman', 'amazar', 'rio grande', 'faanui', 'paris', 'san patricio', 'piacabucu', 'geraldton', 'kovdor', 'kamskiye polyany', 'talara', 'hwange', 'port macquarie', 'cidreira', 'coquimbo', 'hithadhoo', 'aksu', 'louisbourg', 'bairiki', 'yar-sale', 'mizdah', 'galveston', 'margate', 'narsaq', 'warwick', 'mae ramat', 'grand river south east', 'lashio', 'hofn', 'tulun', 'kloulklubed', 'pecos', 'lapeer', 'grindavik', 'raga', 'kutum', 'carlisle', 'tungkang', 'anadyr', 'hovd', 'egvekinot', 'sao felix do xingu', 'ciudad bolivar', 'buala', 'gavrilovka', 'portland', 'auki', 'altay', 'antofagasta', 'sterling', 'morros', 'la ronge', 'belushya guba', 'tromso', 'saint-augustin', 'havelock', 'umm kaddadah', 'yerofey pavlovich', 'kruisfontein', 'abiy adi', 'east london', 'pacific grove', 'tres arroyos', 'dumas', 'dubenskiy', 'pathein', 'concarneau', 'acajutla', 'staunton', 'chingirlau', 'calatayud', 'jiwani', 'suhbaatar', 'cap-aux-meules', 'tadine', 'rawannawi', 'bolshaya rechka', 'taoudenni', 'staraya toropa', 'usolye', 'camacha', 'zelenogorskiy', 'emerald', 'ust-maya', 'puerto cabezas', 'nabire', 'praia da vitoria', 'jumla', 'talnakh', 'finschhafen', 'sioux loo ...

# %%
print(len(cities))
# Out:
# 613

# %% [markdown]
# #### Perform an API call with the OpenWeatherMap.

# %%
# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1eaa7319fad544f224f5dfc098ae6a79

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %% [markdown]
# #### Retrieve information from the API Call
# Lat and long, max temp, % humidity, % cloudiness, wind speed, weather description (e.g., clouds, fog, light rain, clear sky)

# %%
# Create an empty list to hold the weather data.
city_data = []

# Loop through all the cities in our list.
for city in cities:
    
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city
    
    # conditional for 404 code
    city_weather = requests.get(city_url).json()
    code = city_weather["cod"]
    
    if code == 200:
        try: #with rain
            city_weather = requests.get(city_url).json()

            city_lat = city_weather["coord"]["lat"]
            city_lng = city_weather["coord"]["lon"]
            city_max_temp = city_weather["main"]["temp_max"]
            city_humidity = city_weather["main"]["humidity"]
            city_clouds = city_weather["clouds"]["all"]
            city_wind = city_weather["wind"]["speed"]
            city_country = city_weather["sys"]["country"]
            city_desc = city_weather["weather"][0]["description"]
            city_rain = city_weather["rain"]["3h"]
            city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
            
            # Append with rain and no snow
            city_data.append({"City": city.title(),
                              "Country": city_country,
                              "Date": city_date,
                              "Lat": city_lat,
                              "Lng": city_lng,
                              "Max Temp": city_max_temp,
                              "Humidity": city_humidity,
                              "Cloudiness": city_clouds,
                              "Wind Speed": city_wind,
                              "Current Description": city_desc,
                              "Rain Inches (last 3 hrs)": city_rain,
                              "Snow Inches (last 3 hrs)": 0})
            
        except: # if no rain
            try: #with snow
                city_weather = requests.get(city_url).json()
                city_lat = city_weather["coord"]["lat"]
                city_lng = city_weather["coord"]["lon"]
                city_max_temp = city_weather["main"]["temp_max"]
                city_humidity = city_weather["main"]["humidity"]
                city_clouds = city_weather["clouds"]["all"]
                city_wind = city_weather["wind"]["speed"]
                city_country = city_weather["sys"]["country"]
                city_desc = city_weather["weather"][0]["description"]
                city_snow = city_weather["snow"]["3h"]
                city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
                
                # Append with snow, no rain
                city_data.append({"City": city.title(),
                                  "Country": city_country,
                                  "Date": city_date,
                                  "Lat": city_lat,
                                  "Lng": city_lng,
                                  "Max Temp": city_max_temp,
                                  "Humidity": city_humidity,
                                  "Cloudiness": city_clouds,
                                  "Wind Speed": city_wind,
                                  "Current Description": city_desc,
                                  "Rain Inches (last 3 hrs)": 0,
                                  "Snow Inches (last 3 hrs)": city_snow})
                
            except: #if no rain or snow
                # append with snow and rain as 0
                city_weather = requests.get(city_url).json()
                city_lat = city_weather["coord"]["lat"]
                city_lng = city_weather["coord"]["lon"]
                city_max_temp = city_weather["main"]["temp_max"]
                city_humidity = city_weather["main"]["humidity"]
                city_clouds = city_weather["clouds"]["all"]
                city_wind = city_weather["wind"]["speed"]
                city_country = city_weather["sys"]["country"]
                city_desc = city_weather["weather"][0]["description"]
                city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
                
                city_data.append({"City": city.title(),
                                  "Country": city_country,
                                  "Date": city_date,
                                  "Lat": city_lat,
                                  "Lng": city_lng,
                                  "Max Temp": city_max_temp,
                                  "Humidity": city_humidity,
                                  "Cloudiness": city_clouds,
                                  "Wind Speed": city_wind,
                                  "Current Description": city_desc,
                                  "Rain Inches (last 3 hrs)": 0,
                                  "Snow Inches (last 3 hrs)": 0})
    else: #if the code is 404
        pass

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#                City Country                 Date    Lat     Lng  Max Temp  \
# 0             Lagoa      PT  2020-04-19 18:53:32  39.05  -27.98     57.97
# 1             Kapaa      US  2020-04-19 18:52:34  22.08 -159.32     78.01
# 2           Cayenne      GF  2020-04-19 18:56:15   4.93  -52.33     84.20
# 3    Vestmannaeyjar      IS  2020-04-19 18:53:16  63.44  -20.27     44.60
# 4      Richards Bay      ZA  2020-04-19 19:00:44 -28.78   32.04     71.04
# ..              ...     ...                  ...    ...     ...       ...
# 562          Cajati      BR  2020-04-19 19:04:14 -24.74  -48.12     75.07
# 563        Meulaboh      ID  2020-04-19 19:03:50   4.14   96.13     80.02
# 564         Chicama      PE  2020-04-19 18:58:53  -7.84  -79.15     71.60
# 565          Palana      RU  2020-04-19 19:08:19  59.12  159.97      9.68
# 566      Turukhansk      RU  2020-04-19 19:08:20  65.82   87.98     37.99
#
#      Humidity  Cloudiness  Wind Speed Current Description  \
# 0          66          14       28.30          few clouds
# 1          83          75        5.82       broken clouds
# 2          79          97       11.41       moderate rain
# 3         100          90       26.40       moderate rain
# 4          80           0       12.21           clear sky
# ..        ...         ...         ...                 ...
# 562        65          58        3.94          light rain
# 563        82          90        3.65          light rain
# 564        78          22       13.87          few clouds
# 565        95          91        4.52          light snow
# 566        75         100       15.46     overcast clouds
#
#      Rain Inches (last 3 hrs)  Snow Inches (last 3 hrs)
# 0                        0.00                      0.00
# 1                        0.00                      0.00
# 2                        4.38                      0.00
# 3                        0.00                      0.00
# 4                        0.00                      0.00
# ..                        ...                       ...
# 562                      0.51                      0.00
# 563                      1.55                      0.00
# 564                      0.00                      0.00
# 565                      0.00                      0.14
# 566                      0.00                      0.00
#
# [567 rows x 12 columns]

# %%
# Save the new dataframe as a CSV file to be used for Part 2
city_data_df.to_csv('WeatherPy_challenge.csv')

# %%
# Answer "How many cities have recorded rainfall or snow?" using pandas method
cities_rain = (city_data_df['Rain Inches (last 3 hrs)'] != 0).sum()
cities_snow = (city_data_df['Snow Inches (last 3 hrs)'] != 0).sum()

print(f"There are {cities_rain} cities that have recorded rainfall, and {cities_snow} cities with recorded snowfall.")
# Out:
# There are 93 cities that have recorded rainfall, and 13 cities with recorded snowfall.
