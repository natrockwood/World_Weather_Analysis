# %% [markdown]
# ### Get the Weather Description and Amount of Precipitation for Each City

# %%
# Import dependencies

import random
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests
import traceback

# %%
# Create a new set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %% [markdown]
# #### Get the nearest city using the citipy module.

# %%
# Import citipy module
from citipy import citipy

# %%
# Use the tuple() function to display the latitude and longitude combinations.
for coordinate in coordinates:
    print(citipy.nearest_city(coordinate[0], coordinate[1]).city_name,
          citipy.nearest_city(coordinate[0], coordinate[1]).country_code)
# Out:
# pingchen tw
# cherskiy ru
# punta arenas cl
# katsuura jp
# mabaruma gy
# richards bay za
# ushuaia ar
# vaini to
# hilo us
# quelimane mz
# gewane et
# cherskiy ru
# bluff nz
# tuktoyaktuk ca
# albany au
# barentsburg sj
# rabo de peixe pt
# darhan mn
# atuona pf
# tumannyy ru
# punta arenas cl
# mataura pf
# ushuaia ar
# pevek ru
# hermanus za
# grand river south east mu
# sao filipe cv
# aswan eg
# port alfred za
# roma au
# atuona pf
# rikitea pf
# lata sb
# illoqqortoormiut gl
# vaitupu wf
# zhigansk ru
# mataura pf
# kapaa us
# sinkat sd
# hope us
# saint george bm
# saint-francois gp
# tabou ci
# ambagarh chauki in
# khatanga ru
# rey bouba cm
# ziyang cn
# bethel us
# sao joao da barra br
# hobart au
# nome us
# chuy uy
# karakulino ru
# sabzevar ir
# illoqqortoormiut gl
# bengkulu id
# moyo ug
# taolanaro mg
# bluff nz
# dikson ru
# nyuksenitsa ru
# hithadhoo mv
# samusu ws
# dikson ru
# barrow us
# busselton au
# port alfred za
# sant feliu de guixols es
# huilong cn
# miyako jp
# hobart au
# punta arenas cl
# puerto ayora ec
# katsuura jp
# amderma ru
# severo-kurilsk ru
# rikitea pf
# pevek ru
# busselton au
# yellowknife ca
# rikitea pf
# punta arenas cl
# hermanus za
# ushuaia ar
# canar ec
# kiama au
# lebu cl
# taolanaro mg
# itarema br
# uruzgan af
# constantine dz
# kamenskoye ru
# nuuk gl
# hermanus za
# taltal cl
# leningradskiy ru
# punta arenas cl
# rochegda ru
# mataura pf
# tautira pf
# paamiut gl
# ushuaia ar
# atuona pf
# oussouye sn
# batsfjord no
# butaritari ki
# tuktoyaktuk ca
# port alfred za
# barrow us
# hobart au
# saldanha za
# road town vg
# mys shmidta ru
# vallenar cl
# cape town za
# mar del plata ar
# ushuaia ar
# nova olinda do norte br
# tuktoyaktuk ca
# carnarvon au
# rikitea pf
# thompson ca
# saint george bm
# caravelas br
# mar del plata ar
# hermanus za
# mar del plata ar
# norman wells ca
# qaanaaq gl
# ushuaia ar
# bethel us
# hobart au
# mahebourg mu
# cibitoke bi
# tuktoyaktuk ca
# bengkulu id
# mizdah ly
# hermanus za
# bengkulu id
# bossembele cf
# pecanha br
# hermanus za
# tasiilaq gl
# khatanga ru
# ushuaia ar
# kapaa us
# barentsburg sj
# vilhena br
# igrim ru
# mackay au
# tilichiki ru
# busselton au
# orange au
# tasiilaq gl
# ilulissat gl
# jaguaruana br
# new norfolk au
# beringovskiy ru
# hilo us
# castro cl
# olinda br
# cape town za
# caravelas br
# butaritari ki
# vaini to
# new norfolk au
# hithadhoo mv
# mus tr
# puerto ayora ec
# sentyabrskiy ru
# kapaa us
# rosetta eg
# varnamo se
# salalah om
# barentsburg sj
# ribeira grande pt
# jamestown sh
# saint george bm
# albany au
# mataura pf
# jamestown sh
# hobart au
# mehamn no
# puerto ayora ec
# bethel us
# nguiu au
# arraial do cabo br
# busselton au
# cockburn town tc
# phalaborwa za
# atuona pf
# mar del plata ar
# hasaki jp
# butaritari ki
# chuy uy
# yeniseysk ru
# ranong th
# cape town za
# buala sb
# chapais ca
# kodiak us
# busselton au
# caracuaro mx
# ribeira grande pt
# arraial do cabo br
# provideniya ru
# airai pw
# taolanaro mg
# bluff nz
# saint-pierre pm
# mataura pf
# norman wells ca
# ushuaia ar
# ushuaia ar
# rikitea pf
# cranbrook ca
# progreso mx
# hithadhoo mv
# jamestown sh
# kodiak us
# vaini to
# half moon bay us
# dongsheng cn
# illoqqortoormiut gl
# banda aceh id
# port blair in
# zonguldak tr
# tateyama jp
# esperance au
# port elizabeth za
# vila franca do campo pt
# souillac mu
# tiksi ru
# bredasdorp za
# punta arenas cl
# rikitea pf
# ranghulu cn
# yellowknife ca
# kruisfontein za
# cape town za
# cape town za
# tiksi ru
# exeter us
# swift current ca
# northam au
# rikitea pf
# albany au
# bajah tn
# amderma ru
# lubbock us
# keti bandar pk
# castro cl
# vaitupu wf
# avarua ck
# hermanus za
# farafangana mg
# kavaratti in
# corovode al
# chuguyevka ru
# illoqqortoormiut gl
# kavieng pg
# tsihombe mg
# albany au
# punta arenas cl
# newport us
# tres palos mx
# te anau nz
# souillac mu
# formosa br
# safaga eg
# pinawa ca
# evensk ru
# eenhana na
# rikitea pf
# tsihombe mg
# xacmaz az
# ushuaia ar
# hofn is
# jamestown sh
# tuktoyaktuk ca
# quatre cocos mu
# mataura pf
# norilsk ru
# lao cai vn
# longyearbyen sj
# alice springs au
# ikot ekpene ng
# longyearbyen sj
# oranjestad aw
# nisia floresta br
# imuris mx
# clyde river ca
# riyadh sa
# barrow us
# kruisfontein za
# goderich sl
# tasiilaq gl
# hilo us
# qeshm ir
# talnakh ru
# hithadhoo mv
# hermanus za
# coahuayana mx
# bluff nz
# port moresby pg
# urdzhar kz
# shellbrook ca
# ilulissat gl
# bengkulu id
# bredasdorp za
# walvis bay na
# new norfolk au
# lagoa pt
# kasongo-lunda cd
# rikitea pf
# qaanaaq gl
# bolungarvik is
# liaoyang cn
# carballo es
# saint-augustin ca
# upernavik gl
# ust-omchug ru
# hilo us
# takoradi gh
# ushuaia ar
# bredasdorp za
# yarada in
# rikitea pf
# seoul kr
# leningradskiy ru
# pachino it
# batemans bay au
# punta arenas cl
# dikson ru
# atuona pf
# port alfred za
# cape town za
# cape town za
# port alfred za
# barrow us
# zeya ru
# araceli ph
# tongchuan cn
# albany au
# san carlos de bariloche ar
# bluff nz
# erzin ru
# korla cn
# meulaboh id
# bluff nz
# tari pg
# ushuaia ar
# ancud cl
# kruisfontein za
# zeya ru
# nanortalik gl
# samusu ws
# avarua ck
# busselton au
# bethel us
# taolanaro mg
# rikitea pf
# cayenne gf
# rikitea pf
# ilo pe
# codrington ag
# busselton au
# kapaa us
# novikovo ru
# punta arenas cl
# albany au
# rikitea pf
# bria cf
# dawson creek ca
# cape town za
# coquimbo cl
# jamestown sh
# taolanaro mg
# ossora ru
# flinders au
# baykit ru
# owando cg
# jamestown sh
# marcona pe
# carnarvon au
# hilo us
# kodiak us
# bethel us
# hobart au
# cherskiy ru
# nihommatsu jp
# ilulissat gl
# georgetown sh
# busselton au
# illoqqortoormiut gl
# sept-iles ca
# port elizabeth za
# busselton au
# vaini to
# tacuarembo uy
# dunedin nz
# norman wells ca
# sao joao da barra br
# loding no
# jamestown sh
# saint-philippe re
# albany au
# vila franca do campo pt
# airai pw
# yellowknife ca
# mar del plata ar
# bluff nz
# ancud cl
# tezu in
# cape town za
# rio grande br
# taolanaro mg
# tautira pf
# mabaruma gy
# juneau us
# sao miguel do iguacu br
# bredasdorp za
# rawson ar
# rikitea pf
# hofn is
# provideniya ru
# barrow us
# komsomolskiy ru
# busselton au
# plettenberg bay za
# east london za
# cape town za
# kaitangata nz
# ushuaia ar
# bluff nz
# jamestown sh
# provideniya ru
# ribeira grande pt
# port alfred za
# jamestown sh
# kruisfontein za
# naze jp
# falun se
# abalak ne
# hermanus za
# nyakahanga tz
# port alfred za
# vaini to
# krotoszyn pl
# tuktoyaktuk ca
# saint marys us
# kedougou sn
# kodiak us
# san policarpo ph
# rikitea pf
# salalah om
# batagay-alyta ru
# richards bay za
# illoqqortoormiut gl
# taolanaro mg
# cherskiy ru
# hermanus za
# mataura pf
# mar del plata ar
# busselton au
# yellowknife ca
# broken hill au
# alofi nu
# lebu cl
# kodiak us
# los llanos de aridane es
# kaitangata nz
# rikitea pf
# los llanos de aridane es
# yellowknife ca
# qaanaaq gl
# mahebourg mu
# busselton au
# umzimvubu za
# cape town za
# tsihombe mg
# jamestown sh
# bashtanka ua
# taolanaro mg
# zlobin by
# husavik is
# carnarvon au
# hilo us
# taolanaro mg
# clinton us
# san andres co
# busselton au
# luebo cd
# teya ru
# manokwari id
# iqaluit ca
# khatanga ru
# maniitsoq gl
# jumla np
# samusu ws
# henties bay na
# kununurra au
# mataura pf
# meyungs pw
# kavieng pg
# srednekolymsk ru
# ust-kamchatsk ru
# longyearbyen sj
# pevek ru
# port hedland au
# sao filipe cv
# palmer us
# rikitea pf
# cape town za
# port hedland au
# atuona pf
# hamilton bm
# clyde river ca
# ponta do sol cv
# hilo us
# taolanaro mg
# mochitlan mx
# luderitz na
# yulara au
# le port re
# rikitea pf
# thomasville us
# bubaque gw
# hobart au
# tuatapere nz
# vaini to
# pevek ru
# rikitea pf
# kapaa us
# rikitea pf
# qaanaaq gl
# dzhusaly kz
# guanare ve
# kapaa us
# rikitea pf
# haines junction ca
# mildura au
# mys shmidta ru
# arraial do cabo br
# mataura pf
# lusambo cd
# bluff nz
# kaitangata nz
# kiama au
# griffith au
# mataura pf
# san jose gt
# chara ru
# boddam gb
# chuy uy
# %%
# Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
        
print(cities)
# Out:
# ['pingchen', 'cherskiy', 'punta arenas', 'katsuura', 'mabaruma', 'richards bay', 'ushuaia', 'vaini', 'hilo', 'quelimane', 'gewane', 'bluff', 'tuktoyaktuk', 'albany', 'barentsburg', 'rabo de peixe', 'darhan', 'atuona', 'tumannyy', 'mataura', 'pevek', 'hermanus', 'grand river south east', 'sao filipe', 'aswan', 'port alfred', 'roma', 'rikitea', 'lata', 'illoqqortoormiut', 'vaitupu', 'zhigansk', 'kapaa', 'sinkat', 'hope', 'saint george', 'saint-francois', 'tabou', 'ambagarh chauki', 'khatanga', 'rey bouba', 'ziyang', 'bethel', 'sao joao da barra', 'hobart', 'nome', 'chuy', 'karakulino', 'sabzevar', 'bengkulu', 'moyo', 'taolanaro', 'dikson', 'nyuksenitsa', 'hithadhoo', 'samusu', 'barrow', 'busselton', 'sant feliu de guixols', 'huilong', 'miyako', 'puerto ayora', 'amderma', 'severo-kurilsk', 'yellowknife', 'canar', 'kiama', 'lebu', 'itarema', 'uruzgan', 'constantine', 'kamenskoye', 'nuuk', 'taltal', 'leningradskiy', 'rochegda', 'tautira', 'paamiut', 'oussouye', 'batsfjord', 'butaritari', 'saldanha', 'road town', 'mys shmidta', 'vallenar', 'cape town', 'mar del plata', 'nova olinda do norte', 'carnarvon', 'thompson', 'caravelas', 'norman wells', 'qaanaaq', 'mahebourg', 'cibitoke', 'mizdah', 'bossembele', 'pecanha', 'tasiilaq', 'vilhena', 'igrim', 'mackay', 'tilichiki', 'orange', 'ilulissat', 'jaguaruana', 'new norfolk', 'beringovskiy', 'castro', 'olinda', 'mus', 'sentyabrskiy', 'rosetta', 'varnamo', 'salalah', 'ribeira grande', 'jamestown', 'mehamn', 'nguiu', 'arraial do cabo', 'cockburn town', 'phalaborwa', 'hasaki', 'yeniseysk', 'ranong', 'buala', 'chapais', 'kodiak', 'caracuaro', 'provideniya', 'airai', 'saint-pierre', 'cranbrook', 'progreso', 'half moon bay', 'dongsheng', 'banda aceh', 'port blair', 'zonguldak', 'tateyama', 'esperance', 'port elizabeth', 'vila franca do campo', 'souillac', 'tiksi', 'bredasdorp', 'ranghulu', 'kruisfontein', 'exeter', 'swift current', 'northam', 'bajah', 'lubbock', 'keti bandar', 'avarua', 'farafangana', 'kavaratti', 'corovode', 'chuguyevka', 'kavieng', 'tsihombe', 'newport', 'tres palos', 'te anau', 'formosa', 'safaga', 'pinawa', 'evensk', 'eenhana', 'xacmaz', 'hofn', 'quatre cocos', 'norilsk', 'lao cai', 'longyearbyen', 'alice springs', 'ikot ekpene', 'oranjestad', 'nisia floresta', 'imuris', 'clyde river', 'riyadh', 'goderich', 'qeshm', 'talnakh', 'coahuayana', 'port moresby', 'urdzhar', 'shellbrook', 'walvis bay', 'lagoa', 'kasongo-lunda', 'bolungarvik', 'liaoyang', 'carballo', 'saint-augustin', 'upernavik', 'ust-omchug', 'takoradi', 'yarada', 'seoul', 'pachino', 'batemans bay', 'zeya', 'araceli', 'tongchuan', 'san carlos de bariloche', 'erzin', 'korla', 'meulaboh', 'tari', 'ancud', 'nanortalik', 'cayenne', 'garden city', 'kamenka', 'kaihua', 'chagda', 'chokurdakh', 'birnin kebbi', 'conde', 'monzon', 'luanda', 'jalu', 'avera', 'belushya guba', 'davenda', 'boa vista', 'kirakira', 'staryy nadym', 'mana', 'sitka', 'severnyy', 'nioro', 'havoysund', 'goure', 'georgetown', 'termoli', 'luderitz', 'canchungo', 'kroya', 'kaitangata', 'severnoye', 'margate', 'brahmapuri', 'lavrentiya', 'rypin', 'sarangani', 'ust-kamchatsk', 'novyy buyan', 'talara', 'saveh', 'east london', 'angoche', 'katima mulilo', 'tomatlan', 'vardo', 'nosy varika', 'jalingo', 'codrington', 'sobolevo', 'stokmarknes', 'coquimbo', 'batagay', 'guarapari', 'gamba', 'bobrovka', 'kinkala', 'pacifica', 'alta floresta', 'christchurch', 'marcona', 'nikolskoye', 'saskylakh', 'kapit', 'bocaiuva', 'victoria', 'fortuna', 'ternate', 'mahon', 'maun', 'salair', 'hanstholm', 'ahipara', 'lompoc', 'stekolnyy', 'sri aman', 'anadyr', 'kholmogory', 'saurimo', 'kilindoni', 'dingle', 'birjand', 'namibe', 'knoxville', 'gayeri', 'san patricio', 'falavarjan', 'panaba', 'herat', 'faanui', 'navabad', 'karbinci', 'wa', 'santiago', 'san cristobal', 'mahibadhoo', 'beachwood', 'lagunas', 'la rioja', 'manoel urbano', 'churachandpur', 'ratlam', 'nizhniy tsasuchey', 'henties bay', 'palabuhanratu', 'attawapiskat', 'bilibino', 'birao', 'juneau', 'mocuba', 'hudson bay', 'b ...

# %%
print(len(cities))
# Out:
# 601

# %% [markdown]
# #### Perform an API call with the OpenWeatherMap.

# %%
# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1eaa7319fad544f224f5dfc098ae6a79

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %% [markdown]
# #### Retrieve information from the API Call
# Lat and long, max temp, % humidity, % cloudiness, wind speed, weather description (e.g., clouds, fog, light rain, clear sky)

# %%
# Create an empty list to hold the weather data.
city_data = []

# Loop through all the cities in our list.
for city in cities:
    
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city
    
    # conditional for 404 code
    city_weather = requests.get(city_url).json()
    code = city_weather["cod"]
    
    if code == 200:
        try: #with rain
            city_weather = requests.get(city_url).json()

            city_lat = city_weather["coord"]["lat"]
            city_lng = city_weather["coord"]["lon"]
            city_max_temp = city_weather["main"]["temp_max"]
            city_humidity = city_weather["main"]["humidity"]
            city_clouds = city_weather["clouds"]["all"]
            city_wind = city_weather["wind"]["speed"]
            city_country = city_weather["sys"]["country"]
            city_desc = city_weather["weather"][0]["description"]
            city_rain = city_weather["rain"]["3h"]
            city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
            
            # Append with rain and no snow
            city_data.append({"City": city.title(),
                              "Country": city_country,
                              "Date": city_date,
                              "Lat": city_lat,
                              "Lng": city_lng,
                              "Max Temp": city_max_temp,
                              "Humidity": city_humidity,
                              "Cloudiness": city_clouds,
                              "Wind Speed": city_wind,
                              "Current Description": city_desc,
                              "Rain Inches (last 3 hrs)": city_rain,
                              "Snow Inches (last 3 hrs)": 0})
            
        except: # if no rain
            try: #with snow
                city_weather = requests.get(city_url).json()
                city_lat = city_weather["coord"]["lat"]
                city_lng = city_weather["coord"]["lon"]
                city_max_temp = city_weather["main"]["temp_max"]
                city_humidity = city_weather["main"]["humidity"]
                city_clouds = city_weather["clouds"]["all"]
                city_wind = city_weather["wind"]["speed"]
                city_country = city_weather["sys"]["country"]
                city_desc = city_weather["weather"][0]["description"]
                city_snow = city_weather["snow"]["3h"]
                city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
                
                # Append with snow, no rain
                city_data.append({"City": city.title(),
                                  "Country": city_country,
                                  "Date": city_date,
                                  "Lat": city_lat,
                                  "Lng": city_lng,
                                  "Max Temp": city_max_temp,
                                  "Humidity": city_humidity,
                                  "Cloudiness": city_clouds,
                                  "Wind Speed": city_wind,
                                  "Current Description": city_desc,
                                  "Rain Inches (last 3 hrs)": 0,
                                  "Snow Inches (last 3 hrs)": city_snow})
                
            except: #if no rain or snow
                # append with snow and rain as 0
                city_weather = requests.get(city_url).json()
                city_lat = city_weather["coord"]["lat"]
                city_lng = city_weather["coord"]["lon"]
                city_max_temp = city_weather["main"]["temp_max"]
                city_humidity = city_weather["main"]["humidity"]
                city_clouds = city_weather["clouds"]["all"]
                city_wind = city_weather["wind"]["speed"]
                city_country = city_weather["sys"]["country"]
                city_desc = city_weather["weather"][0]["description"]
                city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
                
                city_data.append({"City": city.title(),
                                  "Country": city_country,
                                  "Date": city_date,
                                  "Lat": city_lat,
                                  "Lng": city_lng,
                                  "Max Temp": city_max_temp,
                                  "Humidity": city_humidity,
                                  "Cloudiness": city_clouds,
                                  "Wind Speed": city_wind,
                                  "Current Description": city_desc,
                                  "Rain Inches (last 3 hrs)": 0,
                                  "Snow Inches (last 3 hrs)": 0})
    else: #if the code is 404
        pass

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#              City Country                 Date    Lat     Lng  Max Temp  \
# 0        Cherskiy      RU  2020-04-19 20:58:16  68.75  161.30      4.64
# 1    Punta Arenas      CL  2020-04-19 20:53:57 -53.15  -70.92     44.60
# 2        Katsuura      JP  2020-04-19 20:58:17  35.13  140.30     57.52
# 3        Mabaruma      GY  2020-04-19 20:58:17   8.20  -59.78     81.54
# 4    Richards Bay      ZA  2020-04-19 20:58:18 -28.78   32.04     69.13
# ..            ...     ...                  ...    ...     ...       ...
# 553       Veraval      IN  2020-04-19 21:04:51  20.90   70.37     80.22
# 554        Inuvik      CA  2020-04-19 21:04:52  68.35 -133.72     17.60
# 555        Kailua      US  2020-04-19 21:04:53  21.40 -157.74     82.40
# 556     Ugoofaaru      MV  2020-04-19 21:02:05   5.67   73.00     85.95
# 557        La Paz      BO  2020-04-19 21:04:25 -16.50  -68.15     55.40
#
#      Humidity  Cloudiness  Wind Speed Current Description  \
# 0          93         100        6.87          light snow
# 1          65          40       31.09    scattered clouds
# 2          76         100       10.04          light rain
# 3          75          33        8.97          light rain
# 4          77           0        9.60           clear sky
# ..        ...         ...         ...                 ...
# 553        57           2       11.59           clear sky
# 554        57          90        6.93     overcast clouds
# 555        54           1        9.17           clear sky
# 556        72           0        8.52           clear sky
# 557        43          75       10.29       broken clouds
#
#      Rain Inches (last 3 hrs)  Snow Inches (last 3 hrs)
# 0                        0.00                      0.13
# 1                        0.00                      0.00
# 2                        0.19                      0.00
# 3                        1.06                      0.00
# 4                        0.00                      0.00
# ..                        ...                       ...
# 553                      0.00                      0.00
# 554                      0.00                      0.00
# 555                      0.00                      0.00
# 556                      0.00                      0.00
# 557                      0.00                      0.00
#
# [558 rows x 12 columns]

# %%
# Save the new dataframe as a CSV file to be used for Part 2
city_data_df.to_csv('data\WeatherPy_challenge.csv', index=False)

# %%
# Answer "How many cities have recorded rainfall or snow?" using pandas method
cities_rain = (city_data_df['Rain Inches (last 3 hrs)'] != 0).sum()
cities_snow = (city_data_df['Snow Inches (last 3 hrs)'] != 0).sum()

print(f"There are {cities_rain} cities that have recorded rainfall, and {cities_snow} cities with recorded snowfall.")
# Out:
# There are 76 cities that have recorded rainfall, and 9 cities with recorded snowfall.
